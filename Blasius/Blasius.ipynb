# %% [markdown]
# <a href="https://colab.research.google.com/github/joaochenriques/FluidMechanics2/blob/main/Blasius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple solution of the Blasius boundary layer equations
#
# $$f^{\prime\prime\prime}+\frac 12 f f^\prime = 0$$
#
# subject to the boundary conditions
#
# $$u(x,y=0)=\left.\frac{df}{d\eta}\right|_{\eta=0}=0$$
# $$v(x,y=0)=f(\eta=0)=0$$
# $$u(x,y\rightarrow \infty)=\left.\frac{df}{d\eta}\right|_{\eta=\infty}=1$$

# %%
# import required libs
import numpy as np
from scipy.integrate import odeint
from pylab import *
from IPython.display import Latex
import pandas as pd

# %%
import pathlib
if not pathlib.Path("mpl_utils.py").exists():
  # !curl -O https://raw.githubusercontent.com/joaochenriques/ipynb_libs/main/mpl_utils.py &> /dev/null

import mpl_utils as mut
mut.config_plots()

# %config InlineBackend.figure_formats = ['svg']

# %% [markdown]
# The present numerical solution uses a simple a shooting method.
#
# First, the differential equations is assemble as a first order system using
#
# $$\mathbf{f}
# =
# \begin{pmatrix}
# f\\
# f^\prime\\
# f^{\prime\prime}
# \end{pmatrix}
# =
# \begin{pmatrix}
# f_0\\
# f_1\\
# f_2
# \end{pmatrix}
# $$
#
# giving
#
# $$
# \frac{d}{d \eta}
# \begin{pmatrix}
# f\\
# f^\prime\\
# f^{\prime\prime}
# \end{pmatrix}
# =
# \frac{d}{d \eta}
# \begin{pmatrix}
# f_0\\
# f_1\\
# f_2
# \end{pmatrix}
# =
# \begin{pmatrix}
# f_1\\
# f_2\\
# -\frac 12 f_0 f_2
# \end{pmatrix}
# $$
#
# subject to the boundary conditions
#
# $\displaystyle u(x,y=0)=f_1=0$
# $\displaystyle v(x,y=0)=f_0=0$
#
# and $\displaystyle \left.\frac{d^2f}{d\eta^2}\right|_{\eta=0}$ is changed iteratively until $f_1(\eta=\eta_\max)=1$
#
# where $\eta_\max$ is a large constant, say 12

# %%
def Blasius( f, η ):
    return ( f[1], f[2], -0.5 * f[0] * f[2] )

# %%
ηmax = 12
η = np.linspace( 0, ηmax, ηmax*10+1 )

# %%
f_initial = ( 0.0, 0.0, 0.3 )
solution = odeint( Blasius, f_initial, η )
f = solution.transpose()

plot( f[0], η, label='$f$' )
plot( f[1], η, label='$f\'$' )
plot( f[2], η, label='$f\'\'$' )
ylabel( r'$\eta$')
legend()
grid()
xlim( (-0.1,4) )
ylim( (0,8) );

# %%
f_initial = ( 0.0, 0.0, 0.35 )
solution = odeint( Blasius, f_initial, η )
f = solution.transpose()

plot( f[0], η, label='$f$' )
plot( f[1], η, label='$f\'$' )
plot( f[2], η, label='$f\'\'$' )
ylabel( r'$\eta$')
legend()
grid()
xlim( (-0.1,4) )
ylim( (0,8) );

# %%
f2_Boyd = 0.33205733621519630
f_initial = ( 0.0, 0.0, f2_Boyd )
solution = odeint( Blasius, f_initial, η )
f = solution.transpose()

plot( f[0], η, label='$f$' )
plot( f[1], η, label='$f\'$' )
plot( f[2], η, label='$f\'\'$' )
ylabel( r'$\eta$')
legend()
grid()
xlim( (-0.1,4) )
ylim( (0,8) );
Latex( r'$f^\prime=\left(df/d\eta\right)|_{\eta_\max}=%.14f$' % f[1][-1] )
# Out:
# $f^\prime=\left(df/d\eta\right)|_{\eta_\max}=1.00000000467869$

# %% [markdown]
# Plot of the dimensionless velocity $\displaystyle \frac{u}{U_e}=f_1$

# %%
plot( f[1], η )
xlabel( r'$\frac{u}{U_e}$' )
ylabel( r'$\eta$' )
grid()
xlim( (-0.1,1.1) )
ylim( (0,8) );

# %% [markdown]
# Plot of the dimensionless velocity $\displaystyle \frac{v}{U_e}\sqrt{\text{Re}_x}=\frac 12 \left( \eta f_1 - f_0\right)$

# %%
v = 0.5 * ( η * f[1] - f[0] )

plot( v, η )
xlabel( r'$\frac{v}{U_e}\sqrt{\mathrm{Re}_x}$' )
ylabel( r'$\eta$' )
grid()
xlim( (-0.1,1.1) )
ylim( (0,8) );

# %%
dic = { '$\eta$': η, '$f(\eta)$': f[0], '$u/Ue$': f[1], '$f^{\\prime\\prime}$': f[2] }
df = pd.DataFrame( dic )
pd.set_option('display.max_rows', len(η) )
df
# Out:
#      $\eta$  $f(\eta)$    $u/Ue$  $f^{\prime\prime}$
# 0       0.0   0.000000  0.000000        3.320573e-01
# 1       0.1   0.001660  0.033205        3.320482e-01
# 2       0.2   0.006641  0.066408        3.319839e-01
# 3       0.3   0.014941  0.099599        3.318094e-01
# 4       0.4   0.026560  0.132764        3.314699e-01
# 5       0.5   0.041493  0.165885        3.309110e-01
# 6       0.6   0.059735  0.198937        3.300792e-01
# 7       0.7   0.081277  0.231890        3.289221e-01
# 8       0.8   0.106108  0.264709        3.273893e-01
# 9       0.9   0.134213  0.297354        3.254327e-01
# 10      1.0   0.165572  0.329780        3.230071e-01
# 11      1.1   0.200160  0.361938        3.200715e-01
# 12      1.2   0.237949  0.393776        3.165892e-01
# 13      1.3   0.278903  0.425237        3.125289e-01
# 14      1.4   0.322982  0.456262        3.078654e-01
# 15      1.5   0.370139  0.486789        3.025805e-01
# 16      1.6   0.420321  0.516757        2.966635e-01
# 17      1.7   0.473469  0.546101        2.901117e-01
# 18      1.8   0.529518  0.574758        2.829310e-01
# 19      1.9   0.588396  0.602667        2.751364e-01
# 20      2.0   0.650024  0.629766        2.667516e-01
# 21      2.1   0.714320  0.655998        2.578093e-01
# 22      2.2   0.781193  0.681310        2.483509e-01
# 23      2.3   0.850550  0.705653        2.384261e-01
# 24      2.4   0.922290  0.728982        2.280918e-01
# 25      2.5   0.996311  0.751260        2.174116e-01
# 26      2.6   1.072506  0.772455        2.064546e-01
# 27      2.7   1.150765  0.792544        1.952942e-01
# 28      2.8   1.230977  0.811510        1.840066e-01
# 29      2.9   1.313029  0.829344        1.726694e-01
# 30      3.0   1.396808  0.846044        1.613603e-01
# 31      3.1   1.482201  0.861619        1.501555e-01
# 32      3.2   1.569095  0.876082        1.391281e-01
# 33      3.3   1.657381  0.889453        1.283471e-01
# 34      3.4   1.746950  0.901761        1.178763e-01
# 35      3.5   1.837699  0.913040        1.077726e-01
# 36      3.6   1.929525  0.923330        9.808627e-02
# 37      3.7   2.022333  0.932673        8.885935e-02
# 38      3.8   2.116030  0.941118        8.012590e-02
# 39      3.9   2.210528  0.948716        7.191165e-02
# 40      4.0   2.305747  0.955518        6.423410e-02
# 41      4.1   2.401607  0.961581        5.710278e-02
# 42      4.2   2.498040  0.966957        5.051973e-02
# 43      4.3   2.594978  0.971703        4.448003e-02
# 44      4.4   2.692361  0.975871        3.897259e-02
# 45      4.5   2.790135  0.979514        3.398087e-02
# 46      4.6   2.888248  0.982684        2.948376e-02
# 47      4.7   2.986657  0.985427        2.545643e-02
# 48      4.8   3.085321  0.987790        2.187118e-02
# 49      4.9   3.184204  0.989815        1.869830e-02
# 50      5.0   3.283274  0.991542        1.590679e-02
# 51      5.1   3.382503  0.993008        1.346512e-02
# 52      5.2   3.481868  0.994246        1.134179e-02
# 53      5.3   3.581346  0.995286        9.505912e-03
